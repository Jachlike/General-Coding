# %% [markdown]
# #### Username and Password Request Program!

# %% [markdown]
# #### Whats the thought process

# %%
# 1. first you have to think of the concept username and password concept
  # what statement/statements can we use to 'loop' the user if the attempt fails
  #(while)
# 2. what function can we use to help the user 'input' his/her name
   #placing a condition for it if its the user or not
    # the clause 'loop' user if incorrect username
# 3. expression to evaluate if its the user

# 4. Function to input the users password
  # placing a condition that returns a value if the password is correct
    # statement to end the 'loop'


while True: # what statement/statements can we use to 'loop' the user if the attempt fails
  #(while)
  username = input() #what function can we use to help the user 'input' his/her name
  if username != 'Joe': #placing a condition for it if its the user or not
    continue # the clause 'loop' user if incorrect username
  print("Welcome Joe!Whats the password?") # expression to evaluate if its the user

  password = input() # function to input the users password
  if password == 'swordfish': #  placing a condition that returns a value if the password is correct
    break # statement to end the 'loop'

print("Access Granted!")
# Out:
# Joe
# Welcome Joe!Whats the password?
# swordfish
# Access Granted!
